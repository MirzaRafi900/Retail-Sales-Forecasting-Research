# %% [markdown]
# # Importing Libraries and Load Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)
sns.set_style("whitegrid")

# %%
df = pd.read_json("../Dataset/Raw_Data/rossmann_store_sales.json")

# %% [markdown]
# # Dataset Informations

# %%
print(df.shape)
# Out:
# (1017209, 18)

# %%
df.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         a          a                570.0
# 2              1         a          a              14130.0
# 3              1         c          c                620.0
# 4              1         a          a              29910.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# 1                       11.0                    2007.0       1
# 2                       12.0                    2006.0       1
# 3                        9.0                    2009.0       0
# 4                        4.0                    2015.0       0
#
#    Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 0              NaN              NaN              NaN
# 1             13.0           2010.0  Jan,Apr,Jul,Oct
# 2             14.0           2011.0  Jan,Apr,Jul,Oct
# 3              NaN              NaN              NaN
# 4              NaN              NaN              NaN

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1017209 entries, 0 to 1017208
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Store                      1017209 non-null  int64
#  1   DayOfWeek                  1017209 non-null  int64
#  2   Date                       1017209 non-null  datetime64[us]
#  3   Sales                      1017209 non-null  int64
#  4   Customers                  1017209 non-null  int64
#  5   Open                       1017209 non-null  int64
#  6   Promo                      1017209 non-null  int64
#  7   StateHoliday               1017209 non-null  object
#  8   SchoolHoliday              1017209 non-null  int64
#  9   StoreType                  1017209 non-null  str
#  10  Assortment                 1017209 non-null  str
#  11  CompetitionDistance        1014567 non-null  float64
#  12  CompetitionOpenSinceMonth  693861 non-null   float64
#  13  CompetitionOpenSinceYear   693861 non-null   float64
#  14  Promo2                     1017209 non-null  int64
#  15  Promo2SinceWeek            509178 non-null   float64
#  16  Promo2SinceYear            509178 non-null   float64
#  17  PromoInterval              509178 non-null   str
# dtypes: datetime64[us](1), float64(5), int64(8), object(1), str(3)
# memory usage: 156.9+ MB

# %%
df.describe()
# Out:
#               Store     DayOfWeek                        Date         Sales  \
# count  1.017209e+06  1.017209e+06                     1017209  1.017209e+06
# mean   5.584297e+02  3.998341e+00  2014-04-11 01:30:42.846062  5.773819e+03
# min    1.000000e+00  1.000000e+00         2013-01-01 00:00:00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00         2013-08-17 00:00:00  3.727000e+03
# 50%    5.580000e+02  4.000000e+00         2014-04-02 00:00:00  5.744000e+03
# 75%    8.380000e+02  6.000000e+00         2014-12-12 00:00:00  7.856000e+03
# max    1.115000e+03  7.000000e+00         2015-07-31 00:00:00  4.155100e+04
# std    3.219087e+02  1.997391e+00                         NaN  3.849926e+03
#
#           Customers          Open         Promo  SchoolHoliday  \
# count  1.017209e+06  1.017209e+06  1.017209e+06   1.017209e+06
# mean   6.331459e+02  8.301067e-01  3.815145e-01   1.786467e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    4.050000e+02  1.000000e+00  0.000000e+00   0.000000e+00
# 50%    6.090000e+02  1.000000e+00  0.000000e+00   0.000000e+00
# 75%    8.370000e+02  1.000000e+00  1.000000e+00   0.000000e+00
# max    7.388000e+03  1.000000e+00  1.000000e+00   1.000000e+00
# std    4.644117e+02  3.755392e-01  4.857586e-01   3.830564e-01
#
#        CompetitionDistance  CompetitionOpenSinceMonth  \
# count         1.014567e+06              693861.000000
# mean          5.430086e+03                   7.222866
# min           2.000000e+01                   1.000000
# 25%           7.100000e+02                   4.000000
# 50%           2.330000e+03                   8.000000
# 75%           6.890000e+03                  10.000000
# max           7.586000e+04                  12.000000
# std           7.715324e+03                   3.211832
#
#        CompetitionOpenSinceYear        Promo2  Promo2SinceWeek  \
# count             693861.000000  1.017209e+06    509178.000000
# mean                2008.690228  5.005638e-01        23.269093
# min                 1900.000000  0.000000e+00         1.000000
# 25%                 2006.000000  0.000000e+00        13.000000
# 50%                 2010.000000  1.000000e+00        22.000000
# 75%                 2013.000000  1.000000e+00        37.000000
# max                 2015.000000  1.000000e+00        50.000000
# std                    5.992644  4.999999e-01        14.095973
#
#        Promo2SinceYear
# count    509178.000000
# mean       2011.752774
# min        2009.000000
# 25%        2011.000000
# 50%        2012.000000
# 75%        2013.000000
# max        2015.000000
# std           1.662870

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Missing Values

# %%
df.isnull().sum()
# Out:
# Store                             0
# DayOfWeek                         0
# Date                              0
# Sales                             0
# Customers                         0
# Open                              0
# Promo                             0
# StateHoliday                      0
# SchoolHoliday                     0
# StoreType                         0
# Assortment                        0
# CompetitionDistance            2642
# CompetitionOpenSinceMonth    323348
# CompetitionOpenSinceYear     323348
# Promo2                            0
# Promo2SinceWeek              508031
# Promo2SinceYear              508031
# PromoInterval                508031
# dtype: int64

# %% [markdown]
# ## Observation
#
# The dataset contains missing values primarily in
# competition-related and promotion-related variables.
#
# Missing values were observed in:
#
# - CompetitionDistance (2,642)
# - CompetitionOpenSinceMonth (323,348)
# - CompetitionOpenSinceYear (323,348)
# - Promo2SinceWeek (508,031)
# - Promo2SinceYear (508,031)
# - PromoInterval (508,031)
#
# These missing values will require preprocessing
# before machine learning model development.
# Appropriate imputation strategies will be
# investigated during the data preparation phase.

# %% [markdown]
# ## Duplicate Values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Observation
#
# No duplicate records were identified within the dataset.
#
# This suggests a relatively clean dataset and reduces
# the need for duplicate removal operations during
# the preprocessing stage.

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Sales Distribution Analysis

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    df["Sales"],
    bins=50,
    color="orange"
)

plt.title("Sales Distribution Analysis")

plt.xlabel("Sales")

plt.ylabel("Frequency")

plt.savefig(
    "../Figures/Sales_Distributiom_Analysis.jpeg",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ### Observation
#
# Sales distribution is positively skewed.
#
# Most observations are concentrated at lower
# sales values, while a smaller number exhibit
# significantly higher sales volumes.
#
# This indicates the presence of sales spikes.
# and variability in retail demand.

# %% [markdown]
# ## Store Type VS Sales

# %%
df.groupby("StoreType")["Sales"].mean()

sns.boxplot(
    x="StoreType",
    y="Sales",
    data=df
)

plt.savefig(
    "../Figures/StoreTypes_VS_Sales.jpeg",
    dpi=300,
    bbox_inches="tight"
)

# %% [markdown]
# ### Observation
#
# The sales distribution differs across store types.
#
# Store Type B exhibits a noticeably higher median sales value.
# and greater variability compared to the other store types.
# Store types A, C, and D show relatively similar sales.
# distributions.
#
# This suggests that store characteristics may significantly
# influence sales performance and should be considered during
# the forecasting model development process.

# %%
df.groupby("StoreType")["Sales"].mean().sort_values(
    ascending=False
)

sns.boxplot(
    x="StoreType",
    y="Sales",
    data=df
)

plt.savefig(
    "../Figures/StoreType_Vs_Sales_Average.jpeg",
    dpi=300,
    bbox_inches="tight"
)

# %%
df.groupby("StoreType")["Sales"].agg(
    ["mean","median","min","max"]
).sort_values(
    by="mean",
    ascending=False
)
# Out:
#                    mean  median  min    max
# StoreType
# b          10058.837334  9025.5    0  38722
# a           5738.179710  5618.0    0  41551
# c           5723.629246  5766.0    0  31448
# d           5641.819243  5826.0    0  38037

# %% [markdown]
# ### Observation
#
# Analysis of sales performance across store types
# revealed notable differences.
#
# Store Type B generated the highest average sales.
# (10,058.84) and median sales (9,025.5), which are
# substantially greater than those observed for
# Store Types A, C, and D.
#
# Store Types A, C, and D exhibited relatively
# similar sales characteristics, with mean sales
# around 5,700.
#
# These findings suggest that store type is an
# important explanatory variable and may contribute
# significantly to forecasting accuracy.
